# %% [markdown]
# A következő képek a LEOPARD setuppal készültek 2015.10.13. és 14-e között a 16 szegmensű THC jobb alsó szegmenséről 100k-s statisztikával. A feszültségek a következőek voltak:<br />
# #BD:04,CMD:OK,VAL:0899.4;0800.0;1949.8;2000.2<br />
# Az FW pedig 450 V-on volt.(?)<br />

# %% [markdown]
# Egy egydimenziós scan egy lyukról, melynek közepe 25,55 mm körül van:

# %%
from IPython.display import Image

# %%
Image(filename='Run9065.png')

# %% [markdown]
# Továbbá egy 1D-s térkép két szegmensről, az elsőnek csak a széle látszik a bal oldalt, a jobb oldalin viszont szinte teljesen átmentem. Az egyedi lyukak szépen látszanak.

# %%
Image(filename='Run9061.png')

# %% [markdown]
# Ezek után végeztem két helyen is fókuszáló X-Z scan-eket, melyekből az adódott, hogy az optimális magasság a mostani beállításban a legmagasabb Z állásban van. Ha bemegyek valahogy megemelem a mérőrendszert, hogy magasabb z-k is vizsgálhatóak legyenek. <br />
# A két mérés yield térképei:

# %%
from IPython.display import display
x = Image(filename='Run9060.png') 
y = Image(filename='Run9064.png') 

display(x, y)

# %% [markdown]
# Miután beállítottam a fókuszt, a következő yield és gain térképeket készítettem még:

# %%
from IPython.display import Image
from IPython.display import display
h = Image(filename='Run9062.png') 
k = Image(filename='Run9062Gain.png') 
i = Image(filename='Run9063.png')
display(i,h,k)

# %%
#import Image
#blank_image = Image.new("RGB", (800, 600))
#blank_image.paste('Run9064.png', (0,0))
#blank_image.paste('Run9060.png', (0,300))
#display(blank_image)

# %% [markdown]
# A hibás területről yield térképek különböző sodródási tereknél:

# %%
from IPython.display import Image
from IPython.display import display
h = Image(filename='hibasyield1.png') 
k = Image(filename='hibasyield2.png') 
i = Image(filename='hibasyield3.png')
l = Image(filename='hibasyield4.png')
display(i,h,k,l)

# %% [markdown]
# Egy gain mérés különböző plottolással

# %%
from IPython.display import Image
from IPython.display import display
h = Image(filename='hibaserosites.png') 
k = Image(filename='hibaserosites2.png') 
display(h,k)

# %% [markdown]
# És végül egy ráadás nagy yield map

# %%
from IPython.display import Image
from IPython.display import display
h = Image(filename='nagymap.png') 
display(h)
